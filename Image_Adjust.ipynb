# %%
# !nvidia-smi
# Out:
# Thu Dec 22 16:30:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.65.01    Driver Version: 515.65.01    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:03:00.0 Off |                  Off |
# | N/A   47C    P0    54W / 300W |   8474MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1540      C   ...a3/envs/fastai/bin/python     4109MiB |
# |    0   N/A  N/A     14615      C   ...a3/envs/fastai/bin/python     4363MiB |
# +-----------------------------------------------------------------------------+

# %%
# !pip install tokenizers
# Out:
# Requirement already satisfied: tokenizers in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (0.11.4)

# %%
# !pip install transformers tinydb
# Out:
# Requirement already satisfied: transformers in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (4.21.0)
# Requirement already satisfied: tinydb in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (4.7.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers) (0.11.4)
# Requirement already satisfied: filelock in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers) (2022.4.24)
# Requirement already satisfied: tqdm>=4.27 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: requests in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers) (1.22.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers) (0.8.1)
# Requirement already satisfied: packaging>=20.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->transformers) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->transformers) (3.3)

# %%
# !pip install pytorch_lightning==1.2.10
# Out:
# Requirement already satisfied: pytorch_lightning==1.2.10 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (1.2.10)
# Requirement already satisfied: PyYAML!=5.4.*,>=5.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pytorch_lightning==1.2.10) (6.0)
# Requirement already satisfied: torch>=1.4 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pytorch_lightning==1.2.10) (1.11.0)
# Requirement already satisfied: fsspec[http]>=0.8.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pytorch_lightning==1.2.10) (2022.7.1)
# Requirement already satisfied: numpy>=1.16.6 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pytorch_lightning==1.2.10) (1.22.4)
# Requirement already satisfied: torchmetrics==0.2.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pytorch_lightning==1.2.10) (0.2.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pytorch_lightning==1.2.10) (4.64.0)
# Requirement already satisfied: future>=0.17.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pytorch_lightning==1.2.10) (0.18.2)
# Requirement already satisfied: tensorboard!=2.5.0,>=2.2.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pytorch_lightning==1.2.10) (2.11.0)
# Requirement already satisfied: packaging in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pytorch_lightning==1.2.10) (21.3)
# Requirement already satisfied: aiohttp in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (3.8.1)
# Requirement already satisfied: requests in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (2.28.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (2.15.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.51.1)
# Requirement already satisfied: wheel>=0.26 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.37.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (61.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.3.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (3.4.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (3.20.3)
# Requirement already satisfied: typing_extensions in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from torch>=1.4->pytorch_lightning==1.2.10) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from packaging->pytorch_lightning==1.2.10) (3.0.9)
# Requirement already satisfied: six>=1.9.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from requests->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (2022.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch_lightning==1.2.10) (6.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning==1.2.10) (3.2.0)

# %%
# !pip install torchtext==0.10.0
# Out:
# ERROR: Could not find a version that satisfies the requirement torchtext==0.10.0 (from versions: 0.1.1, 0.2.0, 0.2.1, 0.2.3, 0.3.1, 0.4.0, 0.5.0, 0.6.0, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1)
# ERROR: No matching distribution found for torchtext==0.10.0

# %%
# !gdown https://drive.google.com/uc?id=1AGtoZDyHNm8FyGqwrIFijAE4_CarvwrT
# !gdown https://drive.google.com/uc?id=1n9LRtmKx-uTTIkCWHLgeTpPB_-bp7cn4
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1AGtoZDyHNm8FyGqwrIFijAE4_CarvwrT
# To: /home/user/pictogram_prediction_pt/pictogram_sentences_final_final.json
# 100%|██████████████████████████████████████| 8.27M/8.27M [00:00<00:00, 53.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1n9LRtmKx-uTTIkCWHLgeTpPB_-bp7cn4
# To: /home/user/pictogram_prediction_pt/pictograms.json
# 100%|██████████████████████████████████████| 7.78M/7.78M [00:00<00:00, 47.9MB/s]

# %%
import json
corpus = json.load(open("./pictogram_sentences_final_final.json","r"))

# %%
id_sentences = []
ids_ = []
for sentence in corpus:
  s = []
  for t in sentence['pictograms']:
    if t["id"] is None:
      s.append(t["caption"])
      ids_.append(t["caption"])
    else:
      ids_.append(str(t["id"]))
      s.append(str(t["id"]))
  if len(s) >= 3:
    id_sentences.append(" ".join(s))

# %%
ids_ = list(set(ids_))
len(ids_)
# Out:
# 3675

# %%
CORPUS_PATH = "./corpus.txt"
f = open(CORPUS_PATH,"w")
for s in id_sentences:
  f.write(s+"\n")
f.close()

# %% [markdown]
# ## Criar tokenizer

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.pre_tokenizers import WhitespaceSplit
from tokenizers.processors import BertProcessing

special_tokens = ["[UNK]","[SEP]", "[CLS]", "[PAD]", "[MASK]"]

sense_tokenizer = Tokenizer(WordLevel(unk_token="[UNK]"))
sense_tokenizer.add_special_tokens(special_tokens)
sense_tokenizer.pre_tokenizer = WhitespaceSplit()

sep_token = "[SEP]"
cls_token = "[CLS]"
pad_token = "[PAD]"
unk_token = "[UNK]"
sep_token_id = sense_tokenizer.token_to_id(str(sep_token))
cls_token_id = sense_tokenizer.token_to_id(str(cls_token))
pad_token_id = sense_tokenizer.token_to_id(str(pad_token))
unk_token_id = sense_tokenizer.token_to_id(str(unk_token))

sense_tokenizer.post_processor = BertProcessing(
                (str(sep_token), sep_token_id), (str(cls_token), cls_token_id)
            )

# %%
from tokenizers.trainers import WordLevelTrainer
g = WordLevelTrainer(vocab_size = len(ids_)+5,special_tokens=special_tokens,show_progress=True)
sense_tokenizer.train(files=[CORPUS_PATH],trainer=g)

# %%
TOKENIZER_PATH = "tokenizer.json"
sense_tokenizer.save(TOKENIZER_PATH)

# %%
tokenizer_tokens = set(list(sense_tokenizer.get_vocab().keys()))
len(tokenizer_tokens)
# Out:
# 3668

# %% [markdown]
# ## Ajustar a matriz de embeddings do BERTimbau.

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM, BertForMaskedLM
BASE_MODEL = "neuralmind/bert-base-portuguese-cased"
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
model = BertForMaskedLM.from_pretrained(BASE_MODEL)
finetune_model = BertForMaskedLM.from_pretrained(BASE_MODEL)
# Out:
# Some weights of the model checkpoint at neuralmind/bert-base-portuguese-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at neuralmind/bert-base-portuguese-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from transformers import PreTrainedTokenizerFast

cs_tokenizer = PreTrainedTokenizerFast(tokenizer_file=TOKENIZER_PATH)
cs_tokenizer.pad_token = "[PAD]"
cs_tokenizer.sep_token = "[SEP]"
cs_tokenizer.mask_token = "[MASK]"
cs_tokenizer.cls_token = "[CLS]"
cs_tokenizer.unk_token = "[UNK]"

# %%
from torch import tensor
# Get weights of the old wte
old_wgts = finetune_model.get_input_embeddings().weight.clone().detach()
print(old_wgts.size())
# Get the mean embedding vetor of the old wte
wgts_m = old_wgts.mean(0)

# Initialize vocab size and weights of the new wte
new_vocab_size = len(cs_tokenizer.vocab)
bert_embeddings = model.get_input_embeddings()

new_wgts = old_wgts.new_zeros(new_vocab_size,old_wgts.size(1))
new_wgts.size()

vectors_m = old_wgts.mean(0)
# Out:
# torch.Size([29794, 768])

# %%
from transformers import ViTFeatureExtractor, ViTModel
from PIL import Image
import requests

model_name_or_path = 'google/vit-base-patch16-224'
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name_or_path)
vit_model = ViTModel.from_pretrained(model_name_or_path)
vit_model = vit_model.to("cuda:0")
# Out:
# Some weights of the model checkpoint at google/vit-base-patch16-224 were not used when initializing ViTModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing ViTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['vit.pooler.dense.bias', 'vit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import torch
def get_pictogram_embeddings(id_):
  url = "https://api.arasaac.org/api/pictograms/{0}?download=false".format(id_)
  
  try:
    image = Image.open(requests.get(url, stream=True).raw)
    # image = Image.open("aqui.jpg")
  except:
    print('n')
    return None
  image = image.convert('RGB')


  inputs = feature_extractor(images=image, return_tensors="pt")
  inputs = inputs.to("cuda:0")
  outputs = vit_model(**inputs)
  del inputs
  torch.cuda.empty_cache()
  sequence_output = outputs[0].detach().cpu()
  return sequence_output[0, 0, :]
  
embs = get_pictogram_embeddings("21945")
# embs
# Out:
# /home/user/miniconda3/envs/fastai/lib/python3.10/site-packages/PIL/Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
import torch 
from tqdm import tqdm

for w,i in list(cs_tokenizer.get_vocab().items()):
  
  tokens = []
  if w.isnumeric():
    # print(w)
    pictogram = get_pictogram_embeddings(w)
    if pictogram is not None:
      new_wgts[i] = pictogram
      continue
    else:
      tokens = [w]  
  else:
    tokens = [w]
  
  if len(tokens) > 0:
    ws = " ".join(tokens)
    # print("ww",ws)
    ids = tokenizer.convert_tokens_to_ids(tokenizer.tokenize(ws))
    v_ = bert_embeddings(torch.tensor(ids)).mean(0)
    new_wgts[i] = v_
# Out:
# 37238
# 8151
# ww metal
# 30510
# ww malhava
# 8144
# 2400
# ww voc9
# 34623
# ww nascença
# 17231
# ww capaz
# ww descoberto
# 3022
# 38262
# 2445
# 6227
# 16805
# ww ronronando
# 8716
# 5531
# 5484
# ww deveria
# ww desconfiada
# ww manager
# 2560
# 2752
# 10203
# 38708
# ww calorias
# ww online
# 5841
# 2022
# n
# ww 2022
# 10198
# 32940
# 35941
# ww saiamos
# 35069
# 34615
# 29607
# 8203
# 31801
# ww desintoxicantes
# 37072
# ww felipe
# ww silenciosos
# 27371
# 38007
# 4576
# 36981
# ww publicam
# ww chique
# ww forçado
# 37726
# 8027
# ww latinas
# 6976
# 36886
# 26640
# ww questão
# 17042
# 15485
# 30518
# 2446
# 31706
# 2714
# 37828
# ww tosco
# 29506
# ww batente
# ww trancado
# ww cadê
# 37006
# ww viajei
# 35453
# ww boate
# 28201
# ww copinho
# 6474
# 29276
# 6935
# 26270
# 3322
# 24459
# ww voce
# 37405
# 13640
# 7091
# ww malhei
# ww aumento
# 30642
# ww frescos
# 7014
# ww aniversariante
# 9857
# 2868
# 29306
# ww dói
# ww livremente
# 38562
# ww coma
# 5892
# 24863
# 34002
# 2730
# ww verificar
# 4602
# 24135
# 37798
# 5455
# 2326
# 8095
# 4644
# ww entro
# 31851
# 37587
# 7286
# 26366
# ww certeza
# 28881
# 37864
# 37087
# ww nesse
# 9027
# 34082
# 37671
# ww socorro
# 37832
# ww vôo
# 27006
# ww saquinho
# 38707
# ww vitamines
# 2972
# ww bônus
# ww fogao
# 8487
# 8277
# ww culpado
# 6519
# 5527
# ww amoroso
# ww papelão
# 3007
# 5449
# 31997
# 8072
# 35439
# 5096
# 36502
# 36489
# 2880
# 6896
# ww aguda
# ww tevê
# ww português
# 37937
# 11241
# 37770
# ww chato
# 26845
# 6973
# ww criaturas
# 2953
# 29288
# 7018
# 5371
# ww noturno
# 2732
# 35539
# 27545
# 4653
# 35943
# 35921
# 26296
# 35543
# 6924
# ww musculação
# 36602
# ww catarina
# 10234
# 7148
# 37998
# ww afinal
# ww humano
# 37649
# 4663
# 37228
# 34317
# ww maçãs
# 34205
# 35353
# ww alvaro
# ww papão
# ww dias
# 2684
# ww época
# 11748
# 38146
# 4625
# 36051
# 26515
# 22007
# ww acordo
# 9031
# 8212
# ww atrasos
# ww farto
# 5388
# 37526
# 2572
# 35809
# 34519
# 29258
# 7026
# ww conheci
# 33988
# 6631
# 36480
# ww atrasado
# ww perigoso
# 5973
# 6649
# ww preferido
# 25437
# 5811
# ww dele
# 38613
# 28206
# 6036
# 8602
# 5306
# ww condenado
# 30765
# ww empacotando
# ww sarcástico
# ww virás
# 38231
# 37172
# ww recebi
# 4665
# ww embarquem
# ww errei
# ww das
# 34335
# 3426
# 38572
# ww tinteiro
# 17261
# 3144
# 37246
# 36505
# 37685
# 34284
# 31896
# ww voltarmos
# 11750
# ww destrancada
# 2398
# 7074
# 26022
# 35681
# 27564
# 11238
# 21377
# 2458
# 35441
# 7169
# 25560
# ww [SEP]
# 6538
# 37546
# ww curtiu
# 5526
# ww demos
# 2871
# ww maneira
# ww [PAD]
# 3220
# ww descubra
# ww pertences
# 34941
# 35769
# ww artigo
# ww personagens
# 2464
# 9802
# ww aviar
# ww parecem
# ww sandes
# 35933
# ww quieto
# ww dorme
# ww precisam
# 24895
# 37230
# ww compreendo
# 36019
# ww comê
# ww boteco
# 36548
# 5566
# ww acostumado
# 27717
# 32751
# 3123
# 8619
# 13364
# ww pela
# 9001
# 3149
# ww escolha
# 9151
# ww ventando
# 36768
# 12359
# 3086
# 38110
# ww trapaceiro
# 7814
# 9058
# 26368
# 26090
# 30666
# 10267
# ww autores
# ww puder
# 15525
# 34383
# 2613
# ww roupeiro
# ww generosa
# 28002
# ww intervalo
# ww raramente
# 37811
# 32440
# 37332
# ww comidas
# ww dessas
# 2608
# ww puros
# 4670
# 2358
# ww chás
# ww desaparecido
# 2776
# 36506
# ww certos
# 24721
# 25576
# 26779
# 30194
# ww original
# 16735
# 37240
# ww fofo
# ww sobrevive
# ww machuco
# 25074
# ww modelo
# 25261
# 3155
# 16113
# 26370
# 11683
# ww raro
# 34581
# 11615
# 38100
# 16091
# 31480
# 30700
# ww agir
# 35319
# ww comedor
# ww comemorar
# ww engarrafando
# 2694
# 4750
# ww triangulo
# 38564
# 37658
# ww chamei
# 25151
# 15828
# ww coisas
# 9096
# ww estudei
# ww maduras
# ww campeão
# ww trouxa
# 27073
# 6989
# 37757
# 7305
# ww fizemos
# 3272
# 5504
# 31829
# 38403
# 5548
# 29919
# 38274
# 16833
# 11287
# 6004
# 2747
# 7237
# 29716
# 31356
# 28773
# 10164
# ww desse
# ww animalzinho
# ww xbox360
# 5935
# 34558
# ww funcione
# ww demorando
# ww brasileiros
# 36398
# ww atualizações
# ww sexto
# 37760
# ww faculdade
# 11474
# 6042
# 2341
# ww excessiva
# 2477
# ww respostas
# 27319
# 37810
# ww sirva
# ww marielena
# ww primos
# 36513
# 33914
# ww rasos
# 5563
# 10204
# 3414
# 38490
# 38211
# 20113
# ww dorzinha
# 11316
# ww adora
# 15734
# ww ponha
# ww prestes
# ww comidos
# 27677
# 4568
# ww ideias
# 31478
# ww capítulo
# 8196
# ww caixinha
# 2249
# ww desliguei
# 31165
# ww toxicômano
# ww dela
# ww brincando
# 2609
# ww vazia
# 2640
# ww paguei
# ww sujeito
# 32125
# ww chiques
# ww irmãozinho
# 6965
# 34098
# 10139
# 2841
# 10182
# 6897
# 5399
# ww agua
# 27735
# 37510
# 2479
# 25618
# ww ativa
# ww clientes
# 11383
# ww desci
# ww margarida
# 27109
# ww lateral
# ww levei
# 32376
# 3065
# 2497
# 25948
# 30286
# ww espere
# 37880
# ww animados
# ww inacreditável
# ww viemos
# 10206
# 25900
# 35899
# 28541
# ww treinando
# 9067
# 27057
# 32916
# 11519
# ww rosa
# ww aprendo
# ww comum
# 37064
# 15451
# 8280
# 30965
# 2567
# ww machuque
# ww sandalias
# 37699
# 28709
# 11175
# ww jeito
# 35631
# ww comprador
# 13630
# ww vier
# 4649
# ww responda
# 38686
# 25492
# ww amanteigada
# 7223
# 6149
# 31941
# ww deles
# 37727
# ww comunico
# ww envergonhada
# 3238
# ww doentinho
# ww vontade
# ww portão
# 4707
# ww desculpas
# ww breve
# ww peça
# ww moro
# ww turca
# 37779
# 32438
# 35747
# ww exato
# 37062
# ww gatinha
# 28495
# 15748
# 32396
# ww escondida
# ww abaixo
# ww ajudá
# 2911
# 34639
# ww moramos
# 5382
# ww joguei
# ww tomei
# ww adoro
# ww colorida
# 6039
# 8339
# 9819
# ww negros
# 8661
# ww imediatamente
# ww disney
# ww telefonemas
# 2575
# 32368
# 3129
# 34894
# 7287
# 38571
# ww depende
# ww apavorado
# ww docinho
# 27893
# ww destrancaram
# 2963
# 6943
# ww doido
# 28685
# 36089
# 11403
# 2701
# 2020
# n
# ww 2020
# 38477
# 6052
# 38546
# ww dancei
# 5438
# 26915
# 32080
# ww padrinha
# 33062
# 31670
# 4732
# ww estimação
# ww desespero
# 35051
# 35159
# 29078
# 8389
# 9022
# ww educadas
# 21395
# 8359
# 27365
# 8078
# ww pule
# ww dormente
# ww carona
# 6568
# 31190
# ww rude
# 38401
# 6900
# 8241
# 37320
# 29460
# 3092
# ww aguentava
# 32292
# 36811
# ww prepararemos
# 9839
# 37787
# 9094
# 11471
# ww atrasou
# 6903
# 22619
# 27519
# ww chuviscando
# ww frequência
# 37204
# 7803
# 5375
# 24320
# 5410
# 16745
# ww benefícios
# 35177
# ww querido
# 5545
# 27067
# ww desperdiçar
# 37997
# 2977
# 35835
# 27353
# 35112
# 32964
# 36342
# 26493
# 10160
# 37858
# ww gorda
# ww promessas
# 37101
# ww parados
# ww fazê
# 24760
# ww nescau
# 6637
# 26059
# 36959
# ww familiar
# 2573
# 15327
# ww cova
# 10259
# 30150
# ww devias
# ww tuvéssemos
# 29298
# 32745
# 16445
# 24823
# 2505
# ww descançando
# ww noticiário
# ww acreditavam
# 27005
# 13348
# 2925
# 31151
# ww demoramos
# ww interior
# 33050
# ww luiz
# 4574
# 6019
# ww 10h30
# 29590
# 29735
# 11319
# 4676
# 34320
# 36471
# 4723
# 37931
# 2886
# ww salada
# 21381
# ww passagem
# 29129
# 31191
# 36765
# 4583
# ww ideia
# ww 11h30
# 37373
# 7037
# 3166
# ww inteligente
# 6633
# 32446
# ww falarei
# 23811
# 26153
# 22637
# 32782
# ww pareço
# 8692
# 14660
# ww urubu
# ww rosas
# ww numa
# 8170
# 6942
# ww incrível
# ww cappuccino
# 26929
# ww principal
# ww mail
# ww acolá
# 38074
# ww contrato
# ww durmo
# 6192
# 13356
# 36688
# 5374
# 25849
# 2298
# 3056
# 31955
# 22627
# ww centímetros
# 26164
# ww lazanha
# ww transparência
# ww avaliar
# ww games
# 38083
# 26026
# 3099
# ww daquelas
# ww precioso
# 27093
# 23967
# 3251
# 2565
# 25209
# ww depuís
# ww suculentos
# 2437
# 26809
# 8175
# 2520
# 32390
# 32476
# 2631
# ww estivéssemos
# 35581
# 4945
# ww caçarola
# ww quietas
# ww amiguinhos
# 35565
# 38521
# ww físicos
# ww prendi
# 34681
# 15549
# ww corri
# ww faríamos
# ww tentamos
# ww terminei
# 36373
# ww feira
# ww mozarela
# ww agitado
# 5393
# 31176
# 38066
# 6875
# 4872
# ww difículo
# 24737
# ww cuscuz
# ww voo
# 2322
# 3402
# 7073
# ww 1º
# 37089
# ww diariamente
# 2647
# 31680
# 2294
# 37367
# ww limpinho
# ww exemplo
# 2349
# 36047
# 4780
# ww polenta
# 35685
# ww destes
# 3102
# 4593
# ww frágeis
# ww parqueamento
# ww lendário
# ww descuidado
# ww viesse
# 35939
# ww batons
# 37302
# 7013
# 6210
# ww instantaneamente
# 26439
# ww antibióticos
# 37091
# 15361
# ww curtir
# ww compridas
# 2935
# 24903
# 6953
# ww conectados
# ww filho
# 11214
# 2910
# ww irmos
# ww sítio
# 6916
# 38360
# ww parecia
# 38726
# ww misturadas
# 37061
# ww comeu
# 20123
# ww descontando
# 6963
# ww motivo
# 29901
# 29727
# 9007
# 26162
# 32506
# 38501
# 37345
# 8154
# ww desconfortável
# 38734
# ww bastante
# 32753
# 10194
# 30380
# 7125
# 37771
# 2580
# ww niagara
# ww last
# ww 7h
# 38273
# 2409
# ww miami
# 4747
# ww inteligentes
# 29294
# 27206
# 6995
# 36988
# ww ensolarado
# 4942
# 25502
# ww peguei
# ww deposite
# 10167
# ww suor
# ww vencê
# 28095
# ww lavo
# 4742
# ww lindos
# ww existem
# ww esticadas
# ww recado
# ww trabalhamos
# 20401
# 2909
# 27724
# 25269
# ww enormes
# 38706
# 26889
# 32761
# ww moradores
# 32802
# 11396
# 26861
# 16841
# 27630
# 36563
# 8353
# 29145
# 30393
# ww destrancar
# ww ingresso
# 37525
# 6480
# 30356
# 37974
# ww recentemente
# 37413
# ww chame
# 10303
# 4615
# 9051
# 2436
# 2360
# 16988
# 27408
# 2811
# 27518
# ww ouviste
# ww leem
# 38299
# ww noticias
# 4716
# 32508
# 37824
# 5468
# ww panquecas
# ww sanduichs
# ww assisto
# ww centenários
# 32418
# 29488
# 10173
# ww belém
# 37778
# ww distraido
# 5579
# 8482
# ww resistentes
# 2021
# n
# ww 2021
# 37967
# ww sobrava
# ww continuaria
# 2456
# 3355
# ww estaremos
# 17194
# 21389
# ww costuma
# 2425
# ww excluídos
# ww bebemos
# ww falls
# 36241
# ww devorou
# 31408
# ww bombadil
# 36379
# 6143
# 36131
# 2673
# ww apenas
# 2615
# 10238
# 9103
# 2712
# 2669
# ww exibição
# 11709
# 11191
# 8299
# 22208
# 8544
# ww concentração
# 8318
# 34486
# ww fumo
# 11194
# 28431
# 7180
# 11356
# ww aconteceu
# 37256
# 37796
# ww esquina
# 28435
# 2493
# 30340
# 26905
# ww disso
# 3027
# 32618
# 34171
# ww lojinha
# 8512
# 23847
# 25231
# 2654
# 26144
# 8103
# ww negro
# 15491
# ww milhões
# ww desafiou
# ww frescas
# 27715
# 2410
# 8254
# 36559
# 2330
# 37374
# 150
# n
# ww 150
# 28786
# 8665
# 8995
# ww falso
# 26925
# ww atraso
# ww congelante
# 32412
# 2887
# ww ajude
# ww gabriel
# 5420
# 31871
# 35925
# 31892
# 3417
# ww animado
# 38694
# 2299
# 2978
# 10363
# ww grudou
# 3042
# ww profundamente
# ww termine
# ww malhação
# ww apressado
# ww urgentemente
# 35709
# 26817
# ww esqueci
# 26487
# 38040
# 30012
# 2372
# 37949
# 2317
# ww úmido
# 37662
# 38310
# 34359
# 29516
# ww convidados
# ww existe
# 31682
# ww roberto
# ww califórnia
# ww dupla
# ww hexagonais
# ww tomá
# 36309
# 36109
# 37257
# 29591
# ww pude
# 34824
# ww doidos
# 35945
# 2733
# ww pong
# ww pratinho
# 4770
# 38733
# 36968
# 11344
# 6937
# ww carolina
# 6646
# ww daqui
# 10304
# 36533
# ww apreciam
# ww devem
# 4616
# ww shoyu
# ww freguesia
# ww pretendo
# 6887
# ww convencido
# ww quintal
# 23929
# ww parecendo
# 37262
# 35147
# ww madura
# ww tenhamos
# ww trancando
# ww arrepender
# ww gastou
# ww borrifada
# ww banana
# 2268
# 36145
# 4630
# 28479
# ww retiradas
# ww compêndio
# 37744
# ww florinda
# 2348
# 2632
# 2630
# 32830
# ww mente
# 6561
# 35687
# 21851
# ww brincamos
# 21339
# ww geométrica
# ww prejudiciais
# 35929
# 32588
# 4889
# 36347
# 35393
# ww efeito
# 36655
# ww colheu
# 8087
# ww microondas
# ww parece
# 26196
# 2589
# ww rapidamente
# 30671
# ww apreendeu
# ww triangulos
# ww apague
# ww encontrei
# ww renovado
# 31432
# 4717
# 7079
# ww alfacei
# 33012
# 2614
# ww light
# 38019
# 38394
# 5918
# 37675
# ww sofreu
# 11263
# 29112
# 37659
# ww limonada
# 31460
# 2279
# 2404
# 3113
# ww falsa
# ww mantiveram
# 8488
# ww ótimos
# 7211
# 11725
# ww coreana
# ww ameno
# 15032
# ww voc13
# ww sonhei
# 36368
# 34779
# 35373
# 8363
# ww sapão
# ww nebuloso
# 17004
# 35923
# 29644
# 7039
# 6487
# 34465
# 2532
# ww humor
# ww traumatizado
# ww custou
# 2808
# ww íntimos
# 29959
# ww morro
# 34041
# 28171
# ww abacaxis
# 37673
# 32360
# ww bebo
# 2343
# 8096
# 4695
# 4611
# ww humorado
# 5475
# ww custa
# ww incomode
# 37794
# 6907
# 5447
# 28359
# 12321
# ww pelo
# ww demônio
# 38710
# 4658
# 37711
# 8007
# 6630
# ww egocêntrico
# ww quadradas
# 2455
# ww marinho
# ww contigo
# ww próxima
# 27013
# 38750
# 23745
# 11355
# 8558
# 38000
# ww desconfortavelmente
# 27632
# ww cedo
# ww comia
# ww especificamente
# 37795
# 37661
# ww volume
# ww ação
# ww levante
# 9848
# 2023
# n
# ww 2023
# ww embaixo
# ww carreguei
# 11399
# 11312
# ww provavelmente
# ww normal
# 6569
# ww gelado
# ww acredito
# 11174
# 31857
# 2973
# 21980
# 7032
# 24031
# 8044
# ww portáteis
# ww sairemos
# 11202
# 24797
# 2402
# 2904
# 36612
# 8540
# ww vieram
# 6970
# 2826
# ww do
# 11196
# 38057
# 22755
# 24836
# 37730
# 32444
# 7187
# 4890
# ww turma
# 32007
# ww delícia
# 8718
# ww vodka
# 31148
# 12313
# 38721
# ww costumam
# 37319
# 2803
# 26897
# 22620
# ww interessante
# 4589
# ww xeroxar
# ww matrícula
# 2421
# 33070
# 37063
# 37922
# 34055
# 9187
# 5376
# ww trenzinho
# ww educado
# ww cristiano
# ww flamengo
# ww poderás
# 35449
# 37117
# 25654
# 38600
# 25056
# 3021
# 2888
# 6190
# ww fonógrafa
# 30954
# ww exata
# ww simplesmente
# 5534
# 17054
# ww fomos
# 26455
# 21385
# 2522
# 3151
# 5084
# ww preocupe
# ww quentinhas
# 38001
# 3179
# ww vale
# ww desço
# 29512
# 37484
# 31979
# 36974
# ww tipo
# 19559
# 21559
# 25746
# 24025
# 26405
# 7139
# 30271
# 5523
# 37203
# 32430
# 34743
# 22000
# 27691
# 37286
# 2664
# ww atencioso
# 38444
# ww ao
# 10193
# 30152
# 12266
# 30304
# ww perigosos
# 8648
# 22783
# ww cozinho
# ww estragados
# 9887
# 35721
# ww esfriei
# 35931
# ww devido
# 11685
# ww congelantes
# 25506
# 37377
# ww matemática
# 3302
# 11475
# 25656
# ww especial
# 29374
# 24507
# ww olhem
# ww aeronave
# 29272
# 36758
# 24723
# 37366
# 5898
# ww resiste
# 32088
# 32530
# 36504
# 11953
# 19570
# 16025
# 37103
# 29518
# ww brigadeiro
# 5580
# ww néscau
# 2885
# 30132
# 5970
# 35927
# ww sábado
# 36101
# 26622
# ww trancada
# ww eleger
# ww desmotivado
# ww densa
# 20121
# ww brigadier
# 25026
# 36943
# 28761
# 7028
# 35877
# ww perfeitamente
# 3135
# 11390
# 38529
# 2324
# 9834
# 5798
# 25532
# 7259
# 28967
# 37701
# ww revistados
# ww assaltante
# ww fiz
# ww machuquei
# ww arranjar
# 25453
# ww devemos
# 3118
# 3340
# 6886
# ww 5ª
# 25916
# ww situação
# 2907
# ww daiana
# ww grave
# 35157
# ww cliente
# ww teresa
# ww cadela
# ww caçada
# ww exterior
# 29034
# ww venenoso
# ww faremos
# ww aninhavam
# 9870
# 2889
# ww dever
# 8491
# 36767
# 37556
# 2440
# ww bonés
# 36377
# 25040
# 2474
# ww campinho
# ww ângulos
# ww fortes
# ww paixões
# 11317
# 25075
# ww mexeu
# ww colegial
# 2739
# ww virgula

# %%
from torch import nn

new_wte = nn.Embedding(new_vocab_size,old_wgts.size(1)) # new embeddings
new_wte.weight.data.normal_(mean=0,std=finetune_model.config.initializer_range) 
new_wte.weight.data = new_wgts

finetune_model.resize_token_embeddings(len(cs_tokenizer))
finetune_model.set_input_embeddings(new_wte)
finetune_model.set_output_embeddings(new_wte)

# %%
# finetune_model.save_pretrained('/content/gdrive/MyDrive/Doutorado/Corpus construction/execution/files/adjusted-bertimbau-base-14jul')
finetune_model.save_pretrained('modelo')

# %% [markdown]
# ## Treinamento

# %%
import os
os.environ['TRANSFORMERS_NO_ADVISORY_WARNINGS'] = 'true'
os.environ["TOKENIZERS_PARALLELISM"]="false"

# %%
from transformers import PreTrainedTokenizerFast
TOKENIZER_PATH = "tokenizer.json"
cs_tokenizer = PreTrainedTokenizerFast(tokenizer_file=TOKENIZER_PATH)
cs_tokenizer.pad_token = "[PAD]"
cs_tokenizer.sep_token = "[SEP]"
cs_tokenizer.mask_token = "[MASK]"
cs_tokenizer.cls_token = "[CLS]"
cs_tokenizer.unk_token = "[UNK]"

# %%
f = open("corpus.txt","r")
id_sentences = f.readlines()
id_sentences = [l.rstrip() for l in id_sentences]
id_sentences[0]
# Out:
# '31670 36392 31408 7074 7031 próprio 3218'

# %%
BASE_MODEL = './modelo'
BATCH_SIZE = 768
NUM_WORKERS = 6
MAX_EPOCHS = 200
WARMUP_STEPS = int(MAX_EPOCHS * 0.1)

LEARNING_RATE = 0.00001

LOGS_PATH = "img_logs"
LOGGER_INFO = "200"
LOGGER_VERSION = "1e5"
CHECKPOINTS_PATH = "img_checkpoints"
GPUS = 1
ACCUMULATE_GRAD_BATCHES = 4

# %%
from sklearn.model_selection import train_test_split
TEST_SIZE = 0.33

train_idx, val_idx = train_test_split(list(range(len(id_sentences))), test_size=TEST_SIZE, random_state=32)
test_idx, val_idx = train_test_split(val_idx, test_size=0.5, random_state=3)

# %%
import numpy as np
train_examples = np.array(id_sentences).take(train_idx)
val_examples = np.array(id_sentences).take(val_idx)
test_examples = np.array(id_sentences).take(test_idx)
# test_examples = human_sentences

len(train_examples), len(val_examples),len(test_examples)
# Out:
# (8329, 2052, 2051)

# %%
max_len = 13

def tokenize_function(tokenizer,examples):
    # Remove empty lines
    examples = [line for line in examples if len(line) > 0 and not line.isspace()]
    bert = tokenizer(
        examples,
        padding="max_length",
        max_length=max_len,
        return_special_tokens_mask=True,
        truncation=True
    )
    return bert

val_tokenized_examples = tokenize_function(cs_tokenizer,val_examples)
test_tokenized_examples = tokenize_function(cs_tokenizer,test_examples)
train_tokenized_examples = tokenize_function(cs_tokenizer,train_examples)

# %%
from torch.utils.data import Dataset, Subset
from torch import tensor

class MyDataset(Dataset):
  def __init__(self, examples):

    self.input_ids = examples['input_ids']
    self.attention_mask = examples['attention_mask']
    self.special_tokens_mask = examples['special_tokens_mask']
  
  def __len__(self):
    return len(self.input_ids)
  
  def __getitem__(self, idx):
    input_ids = tensor(self.input_ids[idx])
    attention_mask = tensor(self.attention_mask[idx])
    special_tokens_mask = tensor(self.special_tokens_mask[idx])

    return {
      "input_ids":input_ids, 
      "attention_mask":attention_mask, 
      "special_tokens_mask":special_tokens_mask
    }

train_dataset = MyDataset(train_tokenized_examples)
test_dataset = MyDataset(test_tokenized_examples)
val_dataset = MyDataset(val_tokenized_examples)

# %%
from transformers import DataCollatorForLanguageModeling
data_collator = DataCollatorForLanguageModeling(tokenizer=cs_tokenizer, mlm_probability=0.15)
data_collator2 = DataCollatorForLanguageModeling(tokenizer=cs_tokenizer,mlm=False)

# %%
def top_n_data_collator(examples):
  
  batch = {
      "input_ids" : torch.stack([example['input_ids'] for example in examples]),
      "attention_mask": torch.stack([example['attention_mask'] for example in examples]),
  }
  special_tokens_mask = torch.stack([example['special_tokens_mask'] for example in examples])
  masked_indices = special_tokens_mask.bool()

  mask_labels = special_tokens_mask.clone()
  probability_matrix = mask_labels
  probability_matrix.masked_fill_(torch.tensor(special_tokens_mask, dtype=torch.bool), value=0.0)
  masked_indices = probability_matrix.bool()

  labels = batch['input_ids'].clone()
  
  for i, row in enumerate(special_tokens_mask.bool()):
    # print(torch.where(row==False)[0])
    mask_id = torch.where(row==False)[0][-2]
    masked_indices[i][mask_id] = True
    batch['input_ids'][i][mask_id] = cs_tokenizer.mask_token_id


  labels[~masked_indices] =  -100
  
  batch['labels'] = labels

  return batch

# top_n_data_collator(train_dataset)

# %%
from torch.utils.data import DataLoader
from torch.utils.data.distributed import DistributedSampler

train_dataloader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    collate_fn=data_collator,
    # drop_last = True,
    shuffle=True
)

val_dataloader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    pin_memory=True,
    collate_fn=data_collator,
    # drop_last = True
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    collate_fn=data_collator2,
    pin_memory=True,
)

test_dataloader_topn = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    collate_fn=top_n_data_collator,
    pin_memory=True,
)

# %%
from argparse import ArgumentParser
import math
import torch
import torch.nn as nn
import pytorch_lightning as pl
from pytorch_lightning.metrics.functional import accuracy
from pytorch_lightning.callbacks import ModelCheckpoint
from transformers import get_polynomial_decay_schedule_with_warmup
from transformers import AdamW
import torch.nn.functional as F

# BertForMaskedLM.from_pretrained("neuralmind/bert-base-portuguese-cased")

from transformers import BertLMHeadModel
from transformers import BertForMaskedLM


class LitBertClassifier(pl.LightningModule):
    def __init__(self, pretrained_model_name='bert-large-uncased'):
        super().__init__()
        self.save_hyperparameters()
        self.batch_size = BATCH_SIZE
        self.lr = LEARNING_RATE
        self.train_dataset = train_dataset
        self.bert = BertForMaskedLM.from_pretrained(pretrained_model_name)
        self.topns =[1,9,18,25,36]
      
    
    def freeze_to(self, layers):
      for param in self.bert.bert.encoder.layer[:layers].parameters():
        param.requires_grad = False


    def forward(self, input_ids, attention_mask, labels=None):
        if labels == None:
            return self.bert(
                input_ids=input_ids,
                attention_mask=attention_mask,
            )    
        return self.bert(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels = labels
        )

    def training_step(self, batch, batch_idx):
        outputs = self._shared_step(batch, batch_idx)
        loss = outputs[0]

        self.log("train_loss", loss, on_epoch=True, prog_bar=True,)

        return loss

    # def training_epoch_end(self, outputs):
    #   #print(outputs)
    #   train_loss = torch.stack([x['loss'] for x in outputs]).mean()
    #   self.log("train_loss", train_loss, on_epoch=True, prog_bar=True,)

    def train_dataloader(self):
      return DataLoader(self.train_dataset,batch_size=self.batch_size,num_workers=NUM_WORKERS,pin_memory=True,collate_fn=data_collator)
      # return DataLoader(self.train_dataset, batch_size=self.batch_size)

    def get_accuracy(self, batch, results):
        y_true = tensor([]).to(torch.device("cuda:0"))
        y_pred = tensor([]).to(torch.device("cuda:0"))
        for idx, ipids in enumerate(batch["input_ids"]):

            idxs = (ipids == tokenizer.mask_token_id).nonzero()
            if idxs.size()[0] > 0:
                device = "cuda:0"
                y_true = torch.cat((y_true, batch['labels'][idx][idxs].resize(1, idxs.size()[0])[0]))
                # y_true = y_true + batch['labels'][idx][idxs].resize(1, idxs.size()[0])[0].tolist()

                idxs_2 = tensor([a[0] for a in idxs])
                idxs_2 = idxs_2.to(device)
                res = torch.index_select(results[idx],0,idxs_2).argmax(1)

                y_pred = torch.cat((y_pred,res))
        if len(y_pred) == 0:
            return None
        return accuracy(tensor(y_true),tensor(y_pred))

    def validation_step(self, batch, batch_idx):
        with torch.no_grad():
          result = self._shared_step(batch, batch_idx)
          loss = result[0].detach()
          # return {"loss":loss}
          # perplexity = torch.exp(loss)
          # acc = self.get_accuracy(batch,result[1].clone())
          # self.log("val_ppl", perplexity, on_epoch=True, prog_bar=True,)
          # self.log("val_acc", acc, on_epoch=True, prog_bar=True,)
          # self.log("val_loss", loss, on_epoch=True, prog_bar=True,)

          return {
              "val_loss":loss
          }
    
    def validation_epoch_end(self, outputs):
        val_loss = torch.stack([x['val_loss'] for x in outputs]).mean()
        self.log("val_loss", val_loss, on_epoch=True, prog_bar=True,)
    
    
    def test_step(self, batch, batch_idx):
        with torch.no_grad():
          result = self._shared_step(batch, batch_idx)
          loss = result[0].detach()
          perplexity = torch.exp(loss)
          self.log("test_ppl", perplexity, on_epoch=True, prog_bar=True,)
          self.log("test_loss", loss, on_epoch=True, prog_bar=True,)

          if cs_tokenizer.mask_token_id in batch["input_ids"][0]:

            predictions = F.softmax(result[1], dim=-1)
            labels = batch['labels']
            masked = batch['input_ids']
            n = masked.detach().cpu().numpy()
            predicted = predictions.detach().cpu().numpy()[n == cs_tokenizer.mask_token_id]

            ids = np.argsort(-1*predicted,axis=1)
            for first in self.topns:
              count = 0
              for i, data in enumerate(ids):
                if labels[masked == cs_tokenizer.mask_token_id][i].item() in data[:first]:
                  count += 1
              isin = count/predicted.shape[0]

              self.log("test_"+str(first), isin, on_epoch=True, prog_bar=True,)

          return {
              "test_ppl":perplexity,
              "test_loss":loss
          }
    

    def _shared_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]

        outputs = self.forward(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels
        )

        return outputs

    def configure_optimizers(self):
      # optimizer =  AdamWeightDecayOptimizer(self.parameters(), lr=LEARNING_RATE,betas=(0.9, 0.999), eps=1e-6)
      # scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=LEARNING_RATE, steps_per_epoch=1735, epochs=500,anneal_strategy='linear')
      # return [optimizer],[scheduler]
      optimizer = AdamW(self.parameters(), lr=self.lr,betas=(0.9, 0.999), eps=1e-08, weight_decay=0.01)
      scheduler = {
          'scheduler': get_polynomial_decay_schedule_with_warmup(optimizer, num_warmup_steps=WARMUP_STEPS,num_training_steps=MAX_EPOCHS,lr_end=1e-08),
          # 'scheduler': get_linear_schedule_with_warmup(optimizer,num_warmup_steps=WARMUP_STEPS,num_training_steps=MAX_EPOCHS,last_epoch=-1),
          'name': 'lr'
      }
      return [optimizer],[scheduler]
    
    def backward(self, loss, optimizer, idx):
        loss.backward()

# %%
from pytorch_lightning import loggers as pl_loggers
from pytorch_lightning.callbacks import LearningRateMonitor

tb_logger = pl_loggers.TensorBoardLogger(LOGS_PATH,name=LOGGER_INFO, version=LOGGER_VERSION)
lr_monitor = LearningRateMonitor(logging_interval='epoch')

# %%
checkpoint_callback = ModelCheckpoint(
    dirpath=CHECKPOINTS_PATH,
    filename='bertimbau-base-{epoch:02d}-{val_loss:.2f}',
    mode='min',
    save_last=True
)

# %%
trainer = pl.Trainer(
    accelerator='ddp',
    max_epochs=MAX_EPOCHS,
    logger=tb_logger,
    gpus=GPUS,
    callbacks=[checkpoint_callback,lr_monitor],
    precision=16,
    auto_scale_batch_size="binsearch"
)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.

# %%
bert = LitBertClassifier(BASE_MODEL)

# %%
# trainer.tune(bert)

# %%
trainer.fit(bert,train_dataloader,val_dataloader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type            | Params
# -----------------------------------------
# 0 | bert | BertForMaskedLM | 88.9 M
# -----------------------------------------
# 88.9 M    Trainable params
# 0         Non-trainable params
# 88.9 M    Total params
# 355.454   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Saving latest checkpoint...
# 1

# %%
trainer.test(bert,test_dataloaders=test_dataloader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_loss': 4.663632869720459, 'test_ppl': 106.12989807128906}
# --------------------------------------------------------------------------------
# [{'test_ppl': 106.12989807128906, 'test_loss': 4.663632869720459}]

# %%
trainer.test(bert,test_dataloaders=test_dataloader_topn)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# /tmp/ipykernel_14615/760087086.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   probability_matrix.masked_fill_(torch.tensor(special_tokens_mask, dtype=torch.bool), value=0.0)
# /tmp/ipykernel_14615/760087086.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   probability_matrix.masked_fill_(torch.tensor(special_tokens_mask, dtype=torch.bool), value=0.0)
# /tmp/ipykernel_14615/760087086.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   probability_matrix.masked_fill_(torch.tensor(special_tokens_mask, dtype=torch.bool), value=0.0)
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_1': 0.006825938355177641,
#  'test_18': 0.07752315700054169,
#  'test_25': 0.11214041709899902,
#  'test_36': 0.14627011120319366,
#  'test_9': 0.03705509379506111,
#  'test_loss': 8.146393775939941,
#  'test_ppl': 3456.4541015625}
# --------------------------------------------------------------------------------
# [{'test_ppl': 3456.4541015625,
#   'test_loss': 8.146393775939941,
#   'test_1': 0.006825938355177641,
#   'test_9': 0.03705509379506111,
#   'test_18': 0.07752315700054169,
#   'test_25': 0.11214041709899902,
#   'test_36': 0.14627011120319366}]

# %%
trainer.test(bert,test_dataloaders=test_dataloader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_1': 0.006825938355177641,
#  'test_18': 0.07752315700054169,
#  'test_25': 0.11214041709899902,
#  'test_36': 0.14627011120319366,
#  'test_9': 0.03705509379506111,
#  'test_loss': 4.663632869720459,
#  'test_ppl': 106.12989807128906}
# --------------------------------------------------------------------------------
# [{'test_ppl': 106.12989807128906,
#   'test_loss': 4.663632869720459,
#   'test_1': 0.006825938355177641,
#   'test_9': 0.03705509379506111,
#   'test_18': 0.07752315700054169,
#   'test_25': 0.11214041709899902,
#   'test_36': 0.14627011120319366}]

# %%
checkpoint_name="./img_checkpoints/bertimbau-base-epoch=144-val_loss=4.61.ckpt"
checkpoint = LitBertClassifier.load_from_checkpoint(checkpoint_name)

# %%
trainer.test(checkpoint,test_dataloaders=test_dataloader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_1': 0.006825938355177641,
#  'test_18': 0.07752315700054169,
#  'test_25': 0.11214041709899902,
#  'test_36': 0.14627011120319366,
#  'test_9': 0.03705509379506111,
#  'test_loss': 4.727680206298828,
#  'test_ppl': 113.15918731689453}
# --------------------------------------------------------------------------------
# [{'test_ppl': 113.15918731689453,
#   'test_loss': 4.727680206298828,
#   'test_1': 0.006825938355177641,
#   'test_9': 0.03705509379506111,
#   'test_18': 0.07752315700054169,
#   'test_25': 0.11214041709899902,
#   'test_36': 0.14627011120319366}]

# %%
trainer.test(checkpoint,test_dataloaders=test_dataloader_topn)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# /tmp/ipykernel_14615/760087086.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   probability_matrix.masked_fill_(torch.tensor(special_tokens_mask, dtype=torch.bool), value=0.0)
# /tmp/ipykernel_14615/760087086.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   probability_matrix.masked_fill_(torch.tensor(special_tokens_mask, dtype=torch.bool), value=0.0)
# /tmp/ipykernel_14615/760087086.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   probability_matrix.masked_fill_(torch.tensor(special_tokens_mask, dtype=torch.bool), value=0.0)
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_1': 0.002437835093587637,
#  'test_18': 0.07215992361307144,
#  'test_25': 0.10238907486200333,
#  'test_36': 0.13798147439956665,
#  'test_9': 0.029254022985696793,
#  'test_loss': 8.275978088378906,
#  'test_ppl': 3936.479248046875}
# --------------------------------------------------------------------------------
# [{'test_ppl': 3936.479248046875,
#   'test_loss': 8.275978088378906,
#   'test_1': 0.002437835093587637,
#   'test_9': 0.029254022985696793,
#   'test_18': 0.07215992361307144,
#   'test_25': 0.10238907486200333,
#   'test_36': 0.13798147439956665}]

# %%
# !zip  sym_checkpoints.zip checkpoints -r

# %%
# !zip sym_logs.zip logs -r

# %%
from google.colab import drive
 
drive.mount('/content/gdrive')

# %%
# !cp sym_checkpoints.zip /content/gdrive/MyDrive/Doutorado/Corpus\ construction/execution/files/sym_checkpoints.zip

# %%
# !cp sym_logs.zip /content/gdrive/MyDrive/Doutorado/Corpus\ construction/execution/files/sym_logs.zip
